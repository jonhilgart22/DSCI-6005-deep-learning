# %% [markdown]
# Fit the MNIST dataset
# -----
#
# ![](http://myselph.de/mnistExamples.png)
#
# Starting with the model you architectured in the previous lab, try to create the best classifer!
#
# Here is the [current leaderboard](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html)
#
# We'll also have class leaderboard! The top student team will present at the next class session.

# %% [markdown]
# -----
# Guidelines
# -----
#
# __DOs__:
#
# 1. You can add as many layers as you want
# 1. Each layer be any size
# 1. You can pick any activation function
# 1. Adjust learning rate (do this last; the default is very good)
#
# __DON'T__:
#
# 1. You are restricted to 5 training epochs (for the sake of fast training times)
# 1. You are restricted to a Sequential models (later we'll learn about other models)
# 1. You are restricted to Dense layers (later we'll about other layer types)
# 1. You are restricted to SGD (later we'll learn other optimization techniques)
# 1. You are restricted from using regularization (again later)
#
# -----
#
# Tune by hand to start with to get a "feel" for the parameters. Remember they are probably nonlinear (i.e., an one step change in x will not result in a fixed change in accuracy). Then you are free to use random search, grid search, genetic algorithms, or Bayesian optimization.

# %%
reset -fs

# %%
import keras
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ----
# Prepare data
# ----

# %%
from keras.datasets import mnist

# %%
# Setup train and test splits
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# Convert class vectors to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
from matplotlib import pyplot
from scipy.misc import toimage

# %matplotlib inline

# %%
# Create a grid of 3x3 images
for i in range(0, 9):
    pyplot.subplot(330 + 1 + i)
    pyplot.imshow(toimage(x_train[i]))
    
pyplot.show()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# Munge data
image_size = 784 # 28 x 28

x_train = x_train.reshape(x_train.shape[0], image_size) # Transform from matrix to vector
x_train = x_train.astype('float32')
x_train /= 255 # Normalize inputs from 0-255 to 0.0-1.0

x_test = x_test.reshape(x_test.shape[0], image_size) # Transform from matrix to vector
x_test = x_test.astype('float32')
x_test /= 255 # Normalize inputs from 0-255 to 0.0-1.0

print('Number of train examples:', x_train.shape[0])
print('Number of test examples:', x_test.shape[0])
# Out:
# Number of train examples: 60000
# Number of test examples: 10000

# %%
x_train.shape
# Out:
# (60000, 784)

# %% [markdown]
# ----
# Define architecture
# -----

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
import keras as keras

# %%
# Define model
model = Sequential()

# %%
# Define input layer
layer_input = Dense(units=512, 
                    activation='relu', 
                    input_shape=(image_size,))

model.add(layer_input)

# %%
# Define input layer
layer_input = Dense(units=512, 
                    activation='relu', 
                    input_shape=(image_size,))

model.add(layer_input)

# %%
# Define input layer
layer_input = Dense(units=512, 
                    activation='relu', 
                    input_shape=(image_size,))

model.add(layer_input)

# %%
# Define input layer
layer_input = Dense(units=510, 
                    activation='relu', 
                    input_shape=(image_size,))

model.add(layer_input)

# %%
# # Define another layer
# layer_input = Dense(units=510, 
#                     activation='relu')

# model.add(layer_input)

# %%
# # Define another layer
# layer_input = Dense(units=510, 
#                     activation='relu')

# model.add(layer_input)

# %%
# Define output layers
layer_output = Dense(units=num_classes,
                     activation='softmax')

model.add(layer_output)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_126 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_127 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_128 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_129 (Dense)            (None, 510)               261630
# _________________________________________________________________
# dense_130 (Dense)            (None, 10)                5110
# =================================================================
# Total params: 1,193,972.0
# Trainable params: 1,193,972
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
from keras.optimizers import SGD

# %%
learning_rate = 0.25 #best

model.compile(optimizer=SGD(lr=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ----
# Train model
# -----

# %%
batch_size = 128
epochs = 5 # 20 is good number; But let's limit it to 5

# %%
history = model.fit(x_train, 
                    y_train,
                    batch_size=batch_size, 
                    epochs=epochs,
                    verbose=True, 
                    validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
#  - ETA: 1s - loss: 0.3370 - acc: 0.8974
# Epoch 2/5
# 60000/60000 [==============================] - 14s - loss: 0.1078 - acc: 0.9671 - val_loss: 0.0870 - val_acc: 0.9713
# Epoch 3/5
# 60000/60000 [==============================] - 14s - loss: 0.0699 - acc: 0.9783 - val_loss: 0.0811 - val_acc: 0.9745
# Epoch 4/5
# 60000/60000 [==============================] - 14s - loss: 0.0503 - acc: 0.9840 - val_loss: 0.0700 - val_acc: 0.9772
# Epoch 5/5
# 60000/60000 [==============================] - 15s - loss: 0.0363 - acc: 0.9881 - val_loss: 0.0979 - val_acc: 0.9692

# %%
score = model.evaluate(x_test, 
                       y_test, 
                       verbose=True)
# Out:
#  9984/10000 [============================>.] - ETA: 0s

# %%
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.0979482411667
# Test accuracy: 0.9692

# %% [markdown]
# - grid search learning rate

# %%
import numpy as np

# %%
# test sample for gridsearch 
x_train_sample = x_train[:5000,:]
x_test_sample = x_test[:5000,:]
y_train_sample = y_train[:5000,:]
y_test_sample = y_test[:5000,:]

# %%
learning_rate_test = []
learning_rate_test_loss = []
lambda_ = np.linspace(.1,.7,20)
for i in np.linspace(.1,.7,20):
    learning_rate = i

    model.compile(optimizer=SGD(lr=learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    
    history = model.fit(x_train_sample, 
                    y_train_sample,
                    batch_size=batch_size, 
                    epochs=epochs,
                    verbose=True, 
                    validation_data=(x_test_sample, y_test_sample))
    score = model.evaluate(x_test_sample, 
                       y_test_sample)
    learning_rate_test.append(score[1])
    learning_rate_test_loss.append(score[0])
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])
    print('Learning rate', i)
# Out:
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 1.6393 - acc: 0.5688 - val_loss: 2.6535 - val_acc: 0.3308
# Epoch 2/5
# 5000/5000 [==============================] - 1s - loss: 0.6956 - acc: 0.7900 - val_loss: 0.8699 - val_acc: 0.7036
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 0.4195 - acc: 0.8744 - val_loss: 0.8205 - val_acc: 0.7330
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 0.3013 - acc: 0.9162 - val_loss: 0.5054 - val_acc: 0.8432
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 0.2310 - acc: 0.9344 - val_loss: 0.8429 - val_acc: 0.7448
# Test loss: 0.842929524648
# Test accuracy: 0.7448
# Learning rate 0.1
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 2s - loss: 0.2920 - acc: 0.9208 - val_loss: 0.9715 - val_acc: 0.7374
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 0.1954 - acc: 0.9420 - val_loss: 4.1534 - val_acc: 0.3320
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 0.8404 - acc: 0.8180 - val_loss: 1.5854 - val_acc: 0.5944
# Epoch 4/5
# 5000/5000 [==============================] - 2s - loss: 0.3039 - acc: 0.9180 - val_loss: 2.1610 - val_acc: 0.6092
# Epoch 5/5
# 5000/5000 [==============================] - 2s - loss: 0.3259 - acc: 0.9228 - val_loss: 0.6022 - val_acc: 0.8410
# Test loss: 0.602229552412
# Test accuracy: 0.841
# Learning rate 0.131578947368
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 0.1270 - acc: 0.9664 - val_loss: 0.3087 - val_acc: 0.9056
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 0.0863 - acc: 0.9760 - val_loss: 0.4883 - val_acc: 0.8510
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 0.1072 - acc: 0.9722 - val_loss: 0.2830 - val_acc: 0.9162
# Epoch 4/5
# 5000/5000 [==============================] - 2s - loss: 0.0542 - acc: 0.9850 - val_loss: 0.4496 - val_acc: 0.8734
# Epoch 5/5
# 5000/5000 [==============================] - 2s - loss: 0.0478 - acc: 0.9862 - val_loss: 0.3075 - val_acc: 0.9128
# Test loss: 0.307498158319
# Test accuracy: 0.9128
# Learning rate 0.163157894737
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 0.0308 - acc: 0.9932 - val_loss: 0.2837 - val_acc: 0.9240
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 0.0222 - acc: 0.9958 - val_loss: 0.2940 - val_acc: 0.9202
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 0.0162 - acc: 0.9974 - val_loss: 0.2890 - val_acc: 0.9240
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 0.0110 - acc: 0.9992 - val_loss: 0.2877 - val_acc: 0.9260
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 0.0082 - acc: 0.9992 - val_loss: 0.2962 - val_acc: 0.9242
# Test loss: 0.296157501402
# Test accuracy: 0.9242
# Learning rate 0.194736842105
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 2s - loss: 0.0068 - acc: 0.9998 - val_loss: 0.2940 - val_acc: 0.9250
# Epoch 2/5
# 5000/5000 [==============================] - 1s - loss: 0.0050 - acc: 0.9998 - val_loss: 3.3983 - val_acc: 0.5894
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 1.7978 - acc: 0.7140 - val_loss: 0.5362 - val_acc: 0.8522
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 0.2140 - acc: 0.9416 - val_loss: 0.5008 - val_acc: 0.8572
# Epoch 5/5
# 5000/5000 [==============================] - 2s - loss: 0.0914 - acc: 0.9740 - val_loss: 0.2960 - val_acc: 0.9112
# Test loss: 0.296045914155
# Test accuracy: 0.9112
# Learning rate 0.226315789474
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 0.0466 - acc: 0.9890 - val_loss: 0.3128 - val_acc: 0.9094
# Epoch 2/5
# 5000/5000 [==============================] - 1s - loss: 0.0224 - acc: 0.9950 - val_loss: 0.3318 - val_acc: 0.9082
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 0.0133 - acc: 0.9980 - val_loss: 0.2891 - val_acc: 0.9206
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 0.0058 - acc: 0.9998 - val_loss: 0.2900 - val_acc: 0.9250
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 0.0044 - acc: 0.9998 - val_loss: 0.2922 - val_acc: 0.9250
# Test loss: 0.292181346352
# Test accuracy: 0.925
# Learning rate 0.257894736842
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 0.0033 - acc: 0.9996 - val_loss: 0.3065 - val_acc: 0.9248
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 0.0055 - acc: 0.9994 - val_loss: 0.3107 - val_acc: 0.9244
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 0.0029 - acc: 0.9998 - val_loss: 0.3097 - val_acc: 0.9244
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.3237 - val_acc: 0.9234
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 0.0013 - acc: 1.0000 - val_loss: 0.3173 - val_acc: 0.9270
# Test loss: 0.317251512152
# Test accuracy: 0.927
# Learning rate 0.289473684211
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 0.0010 - acc: 1.0000 - val_loss: 0.3218 - val_acc: 0.9270
# Epoch 2/5
# 5000/5000 [==============================] - 1s - loss: 8.6874e-04 - acc: 1.0000 - val_loss: 0.3249 - val_acc: 0.9280
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 7.5415e-04 - acc: 1.0000 - val_loss: 0.3293 - val_acc: 0.9276
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 6.6822e-04 - acc: 1.0000 - val_loss: 0.3323 - val_acc: 0.9284
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 6.0577e-04 - acc: 1.0000 - val_loss: 0.3345 - val_acc: 0.9284
# Test loss: 0.334477952327
# Test accuracy: 0.9284
# Learning rate 0.321052631579
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 5.5378e-04 - acc: 1.0000 - val_loss: 0.3370 - val_acc: 0.9284
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 5.0203e-04 - acc: 1.0000 - val_loss: 0.3583 - val_acc: 0.9248
# Epoch 3/5
# 5000/5000 [==============================] - 2s - loss: 7.0406e-04 - acc: 1.0000 - val_loss: 0.3408 - val_acc: 0.9278
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 4.4209e-04 - acc: 1.0000 - val_loss: 0.3433 - val_acc: 0.9278
# Epoch 5/5
# 5000/5000 [==============================] - 2s - loss: 3.9881e-04 - acc: 1.0000 - val_loss: 0.3441 - val_acc: 0.9272
# Test loss: 0.344132268475
# Test accuracy: 0.9272
# Learning rate 0.352631578947
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 3.6849e-04 - acc: 1.0000 - val_loss: 0.3455 - val_acc: 0.9272
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 3.4510e-04 - acc: 1.0000 - val_loss: 0.3478 - val_acc: 0.9272
# Epoch 3/5
# 5000/5000 [==============================] - 2s - loss: 3.1548e-04 - acc: 1.0000 - val_loss: 0.3528 - val_acc: 0.9254
# Epoch 4/5
# 5000/5000 [==============================] - 2s - loss: 3.0266e-04 - acc: 1.0000 - val_loss: 0.3517 - val_acc: 0.9272
# Epoch 5/5
# 5000/5000 [==============================] - 2s - loss: 2.7700e-04 - acc: 1.0000 - val_loss: 0.3529 - val_acc: 0.9280
# Test loss: 0.352948531525
# Test accuracy: 0.928
# Learning rate 0.384210526316
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 2.6083e-04 - acc: 1.0000 - val_loss: 0.3542 - val_acc: 0.9284
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 2.4576e-04 - acc: 1.0000 - val_loss: 0.3566 - val_acc: 0.9286
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 2.3292e-04 - acc: 1.0000 - val_loss: 0.3579 - val_acc: 0.9286
# Epoch 4/5
# 5000/5000 [==============================] - 2s - loss: 2.2050e-04 - acc: 1.0000 - val_loss: 0.3604 - val_acc: 0.9278
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 2.1020e-04 - acc: 1.0000 - val_loss: 0.3618 - val_acc: 0.9280
# 5000/5000 [==============================] - 1s
# Test loss: 0.361846963767
# Test accuracy: 0.928
# Learning rate 0.415789473684
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 2.0086e-04 - acc: 1.0000 - val_loss: 0.3626 - val_acc: 0.9284
# Epoch 2/5
# 5000/5000 [==============================] - 1s - loss: 1.8943e-04 - acc: 1.0000 - val_loss: 0.3636 - val_acc: 0.9286
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 1.8073e-04 - acc: 1.0000 - val_loss: 0.3643 - val_acc: 0.9290
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 1.7207e-04 - acc: 1.0000 - val_loss: 0.3643 - val_acc: 0.9282
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 1.6673e-04 - acc: 1.0000 - val_loss: 0.3665 - val_acc: 0.9288
# Test loss: 0.366460035363
# Test accuracy: 0.9288
# Learning rate 0.447368421053
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 1.5771e-04 - acc: 1.0000 - val_loss: 0.3701 - val_acc: 0.9272
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 1.5269e-04 - acc: 1.0000 - val_loss: 0.3698 - val_acc: 0.9284
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 1.4513e-04 - acc: 1.0000 - val_loss: 0.3704 - val_acc: 0.9286
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 1.3860e-04 - acc: 1.0000 - val_loss: 0.3707 - val_acc: 0.9286
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 1.3562e-04 - acc: 1.0000 - val_loss: 0.3718 - val_acc: 0.9284
# Test loss: 0.371818374776
# Test accuracy: 0.9284
# Learning rate 0.478947368421
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 1.2874e-04 - acc: 1.0000 - val_loss: 0.3719 - val_acc: 0.9286
# Epoch 2/5
# 5000/5000 [==============================] - 1s - loss: 1.2342e-04 - acc: 1.0000 - val_loss: 0.3723 - val_acc: 0.9286
# Epoch 3/5
# 5000/5000 [==============================] - 2s - loss: 1.1914e-04 - acc: 1.0000 - val_loss: 0.3752 - val_acc: 0.9284
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 1.1507e-04 - acc: 1.0000 - val_loss: 0.3733 - val_acc: 0.9282
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 1.1308e-04 - acc: 1.0000 - val_loss: 0.3763 - val_acc: 0.9286
# Test loss: 0.376346809979
# Test accuracy: 0.9286
# Learning rate 0.510526315789
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 1.0642e-04 - acc: 1.0000 - val_loss: 0.3775 - val_acc: 0.9282
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 1.0270e-04 - acc: 1.0000 - val_loss: 0.3786 - val_acc: 0.9284
# Epoch 3/5
# 5000/5000 [==============================] - 2s - loss: 9.9193e-05 - acc: 1.0000 - val_loss: 0.3792 - val_acc: 0.9288
# Epoch 4/5
# 5000/5000 [==============================] - 2s - loss: 9.5853e-05 - acc: 1.0000 - val_loss: 0.3804 - val_acc: 0.9284
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 9.2844e-05 - acc: 1.0000 - val_loss: 0.3808 - val_acc: 0.9290
# Test loss: 0.380788457113
# Test accuracy: 0.929
# Learning rate 0.542105263158
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 8.9977e-05 - acc: 1.0000 - val_loss: 0.3814 - val_acc: 0.9286
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 8.7005e-05 - acc: 1.0000 - val_loss: 0.3824 - val_acc: 0.9290
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 8.4207e-05 - acc: 1.0000 - val_loss: 0.3830 - val_acc: 0.9290
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 8.1881e-05 - acc: 1.0000 - val_loss: 0.3840 - val_acc: 0.9286
# Epoch 5/5
# 5000/5000 [==============================] - 2s - loss: 7.9403e-05 - acc: 1.0000 - val_loss: 0.3849 - val_acc: 0.9286
# Test loss: 0.384887609252
# Test accuracy: 0.9286
# Learning rate 0.573684210526
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 7.7331e-05 - acc: 1.0000 - val_loss: 0.3860 - val_acc: 0.9288
# Epoch 2/5
# 5000/5000 [==============================] - 1s - loss: 7.5137e-05 - acc: 1.0000 - val_loss: 0.3865 - val_acc: 0.9288
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 7.2866e-05 - acc: 1.0000 - val_loss: 0.3871 - val_acc: 0.9290
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 7.0847e-05 - acc: 1.0000 - val_loss: 0.3885 - val_acc: 0.9292
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 6.9196e-05 - acc: 1.0000 - val_loss: 0.3888 - val_acc: 0.9286
# 5000/5000 [==============================] - 1s
# Test loss: 0.388811738355
# Test accuracy: 0.9286
# Learning rate 0.605263157895
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 6.7199e-05 - acc: 1.0000 - val_loss: 0.3896 - val_acc: 0.9284
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 6.5254e-05 - acc: 1.0000 - val_loss: 0.3901 - val_acc: 0.9286
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 6.3607e-05 - acc: 1.0000 - val_loss: 0.3906 - val_acc: 0.9290
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 6.2003e-05 - acc: 1.0000 - val_loss: 0.3919 - val_acc: 0.9284
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 6.0338e-05 - acc: 1.0000 - val_loss: 0.3922 - val_acc: 0.9292
# 5000/5000 [==============================] - 1s
# Test loss: 0.392233720995
# Test accuracy: 0.9292
# Learning rate 0.636842105263
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 3s - loss: 5.8848e-05 - acc: 1.0000 - val_loss: 0.3927 - val_acc: 0.9290
# Epoch 2/5
# 5000/5000 [==============================] - 2s - loss: 5.7493e-05 - acc: 1.0000 - val_loss: 0.3937 - val_acc: 0.9290
# Epoch 3/5
# 5000/5000 [==============================] - 2s - loss: 5.5958e-05 - acc: 1.0000 - val_loss: 0.3946 - val_acc: 0.9290
# Epoch 4/5
# 5000/5000 [==============================] - 1s - loss: 5.4623e-05 - acc: 1.0000 - val_loss: 0.3949 - val_acc: 0.9286
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 5.3245e-05 - acc: 1.0000 - val_loss: 0.3955 - val_acc: 0.9286
# Test loss: 0.395487761304
# Test accuracy: 0.9286
# Learning rate 0.668421052632
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/5
#  - ETA: 1s - loss: 4.8896e-05 - acc: 1.0000
# Epoch 2/5
# 5000/5000 [==============================] - 1s - loss: 5.1167e-05 - acc: 1.0000 - val_loss: 0.3964 - val_acc: 0.9288
# Epoch 3/5
# 5000/5000 [==============================] - 1s - loss: 4.9473e-05 - acc: 1.0000 - val_loss: 0.3970 - val_acc: 0.9288
# Epoch 4/5
# 5000/5000 [==============================] - 2s - loss: 4.8259e-05 - acc: 1.0000 - val_loss: 0.3981 - val_acc: 0.9284
# Epoch 5/5
# 5000/5000 [==============================] - 1s - loss: 4.7231e-05 - acc: 1.0000 - val_loss: 0.3988 - val_acc: 0.9286
# Test loss: 0.39876599124
# Test accuracy: 0.9286
# Learning rate 0.7

# %%
np.argmax(np.array(learning_rate_test_loss))
# Out:
# 0

# %%
lambdas_ = [_ for _ in np.linspace(.1,.7,20)]

# %%
lambdas_[np.argmax(np.array(learning_rate_test))] # best lambda
# Out:
# 0.63684210526315788

# %%
plt.plot([_ for _ in np.linspace(.1,.7,20)],learning_rate_test)

# %%
# best learning rate at  with two hidden layers .63

# %%
# results
# default three layers with learning rate at .1 = 92%
# four layers, two hidden layers, accuracy of 93.3%
# two hidden layers, with sigmoid activation for second layer, accuracy of 88%
# three hidden layers (all relu), 93.7%
# three hidden layers, (last softamx) - acuracy 11%
# three hidden layers, size of 1024 nodes, 93.5%
# four hidden layers, 100 units, all relu 93.3%
# four hidden layers, sigmoid and relu 100-1000nodes per hidden layer 85%
# five layers, all relu, 100 nodes 93.08%
# five layers, all relu, 100 nodes learning rate of .10 - 9.8%
# three hidden layers, 512 nodes, learning rate .10, all relu, -96% 
# four hidden layers, 512 nodes, learning rate .10, all relu, -97.5%
# five hidden layers, 512 nodes, learning rate .10, all relu, - 96.5%

# %% [markdown]
# What are the __most important__ hyperparameters to adjust improve training accuracy?

# %%
# the learning rate is the most important to improve training accuracy

# %% [markdown]
# What are the __least important__ hyperparameters to adjust improve training accuracy?

# %%
# the size of the input layer

# %% [markdown]
# Which of the __DON'T__ tunning options do think will make the biggest difference?

# %%
# regularization by using dropout
# Also, incresing the number of epochs will help

# %% [markdown]
# A note on significance of improvement
# -----
#
# How significant would an improvement from 0.98 to 0.993 be?
#
# Remember that the original impetus for MNIST etc was the USPS wanting to reduce the number of items that needed to be handled by a postal worker.
#
# At one point, the USPS handled 510 million items each day.
#
# Accuracy of 0.98 (2% error rate) would mean 10.2 million items that have to be touched by a human - either the zip code read or the piece of mail picked up at the wrong address and delivered a second time.
#
# By contrast accuracy of 0.993 means 3.7 millions items that need human intervention.

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
