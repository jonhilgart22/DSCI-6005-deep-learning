# %% [markdown]
# # Multi-Class Logistic Regression
#
# - Grid-search over regularization term

# %%
reset -fs

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from train import ex
import keras.backend as K

for reg in [1e-1, 1e-6, 1e-12]:
    ex.run(config_updates={'reg': reg})
    K.clear_session()
# Out:
# Using TensorFlow backend.
# INFO - test - Running command 'main'
# WARNING - test - No observers have been added to this run
# INFO - test - Started
# /Users/jonathanhilgart/DSCI6005-student/week_5_reinforcement_learning/5_2_pm_nn_training_II/code/trainers.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=10, kernel_regularizer=<keras.reg...)`
#   model.add(Dense(units=self.Y[0].shape[0], W_regularizer=l2(self.C['reg'])))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                7850
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# ...
# Total params: 7,850.0
# Trainable params: 7,850.0
# Non-trainable params: 0.0
# ...

# %% [markdown]
# # CNN gridsearch

# %%
from train import ex
import keras.backend as K

for hidden_size in [1, 64, 256]:
    K.clear_session()
    ex.run(config_updates={'trainer': 'CNNTrainer', 'hidden_size': hidden_size})
# Out:
# Using TensorFlow backend.
# INFO - test - Running command 'main'
# WARNING - test - No observers have been added to this run
# INFO - test - Started
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 27, 27, 32)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                92170
# ...

# %% [markdown]
# # Multi-Layer Perceptron
#
# - Grid-search over hidden layer size

# %%
from train import ex
import keras.backend as K

for hidden_size in [1, 64, 256]:
    K.clear_session()
    ex.run(config_updates={'trainer': 'MLPTrainer', 'hidden_size': hidden_size})
# Out:
# INFO - test - Running command 'main'
# WARNING - test - No observers have been added to this run
# INFO - test - Started
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 785
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                20
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# ...
# Total params: 805
# Trainable params: 805
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# ...
