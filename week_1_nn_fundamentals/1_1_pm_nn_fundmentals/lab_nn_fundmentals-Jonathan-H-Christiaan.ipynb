# %% [markdown]
# Lab: neural network fundamentals
# -----

# %%
reset -fs

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from pandas import DataFrame

# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from neural_network import *

# %% [markdown]
# TODO: Create 2d array for X
#
# X[:,0] is from (0, n), where is n is 30 to start
# X[:,1] are random numbers

# %%
X = np.array([[i,np.random.randn()] for i in range(31)])

# %%
#normalize the data
X = X/np.amax(X, axis=0)
X
# Out:
# array([[  0.00000000e+00,   1.38722505e-01],
#        [  3.33333333e-02,   4.26953555e-05],
#        [  6.66666667e-02,   1.00000000e+00],
#        [  1.00000000e-01,  -9.74293040e-02],
#        [  1.33333333e-01,   8.05234919e-01],
#        [  1.66666667e-01,  -2.35053928e-01],
#        [  2.00000000e-01,   5.00892806e-01],
#        [  2.33333333e-01,   3.01147083e-01],
#        [  2.66666667e-01,   2.66882218e-01],
#        [  3.00000000e-01,  -9.18584174e-01],
#        [  3.33333333e-01,  -6.41068723e-01],
#        [  3.66666667e-01,   4.87170760e-01],
#        [  4.00000000e-01,  -1.59082509e+00],
#        [  4.33333333e-01,  -4.60823252e-01],
#        [  4.66666667e-01,   4.50756991e-01],
#        [  5.00000000e-01,  -5.95820296e-01],
#        [  5.33333333e-01,  -2.82955745e-01],
#        [  5.66666667e-01,   5.40458587e-02],
#        [  6.00000000e-01,   6.79130126e-01],
#        [  6.33333333e-01,  -5.52564730e-01],
#        [  6.66666667e-01,  -4.06531201e-01],
#        [  7.00000000e-01,  -1.22205241e+00],
#        [  7.33333333e-01,  -1.16380601e+00],
#        [  7.66666667e-01,   6.63132979e-01],
#        [  8.00000000e-01,  -5.64531078e-02],
#        [  8.33333333e-01,  -8.76711092e-01],
#        [  8.66666667e-01,  -1.15222454e+00],
#        [  9.00000000e-01,  -8.15302646e-01],
#        [  9.33333333e-01,  -6.51888919e-01],
#        [  9.66666667e-01,   2.38783959e-01],
#        [  1.00000000e+00,   2.21158997e-01]])

# %% [markdown]
# TODO: Create y, where y is the following function of X[:,0]

# %%
poly_function = lambda x: 2 + 0.5 * x + 3 * x ** 2 + 5 * stats.norm.rvs(0, 10)

# %%
y_first = poly_function(X[:,0])

# %%
# get the correct shape
y_first = y_first.reshape(-1,1)

# %%
#normalize the y
y_first =y_first/np.amax(y_first, axis=0)

# %%
y_first
# Out:
# array([[ 0.83679486],
#        [ 0.83772746],
#        [ 0.83897093],
#        [ 0.84052526],
#        [ 0.84239046],
#        [ 0.84456653],
#        [ 0.84705347],
#        [ 0.84985127],
#        [ 0.85295994],
#        [ 0.85637948],
#        [ 0.86010988],
#        [ 0.86415115],
#        [ 0.86850329],
#        [ 0.87316629],
#        [ 0.87814016],
#        [ 0.8834249 ],
#        [ 0.8890205 ],
#        [ 0.89492698],
#        [ 0.90114432],
#        [ 0.90767252],
#        [ 0.91451159],
#        [ 0.92166153],
#        [ 0.92912234],
#        [ 0.93689401],
#        [ 0.94497655],
#        [ 0.95336996],
#        [ 0.96207423],
#        [ 0.97108938],
#        [ 0.98041538],
#        [ 0.99005226],
#        [ 1.        ]])

# %% [markdown]
# TODO: Plot X and y

# %%
sns.regplot(X[:,0],y_first, fit_reg=False)

# %%
# noise
sns.regplot(X[:,1],y_first, fit_reg=False)

# %% [markdown]
# TODO: Train the NN from lecture

# %%
nn = NeuralNetwork()

# %%
t = Trainer(nn)
t.train(X, y_first, maxiter=100)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.001420
#          Iterations: 100
#          Function evaluations: 105
#          Gradient evaluations: 105

# %% [markdown]
# TODO: Plot observed for y. On the same figure, plot predicted for y. The domain is X[:,0].

# %%
DataFrame({'y predicted': t.N.y_hat.flatten().tolist(),
           'y observed': y_first.flatten().tolist()})
# Out:
#     y observed  y predicted
# 0     0.836795     0.825094
# 1     0.837727     0.826483
# 2     0.838971     0.834385
# 3     0.840525     0.830762
# 4     0.842390     0.837754
# 5     0.844567     0.836065
# 6     0.847053     0.842308
# 7     0.849851     0.845360
# 8     0.852960     0.849448
# 9     0.856379     0.851219
# 10    0.860110     0.857875
# 11    0.864151     0.864633
# 12    0.868503     0.867169
# 13    0.873166     0.877278
# 14    0.878140     0.883218
# 15    0.883425     0.891025
# 16    0.889021     0.898130
# 17    0.894927     0.904757
# 18    0.901144     0.909834
# 19    0.907673     0.918771
# 20    0.914512     0.925349
# 21    0.921662     0.930107
# 22    0.929122     0.936135
# 23    0.936894     0.941935
# 24    0.944977     0.948487
# 25    0.953370     0.952401
# 26    0.962074     0.956023
# 27    0.971089     0.961083
# 28    0.980415     0.965205
# 29    0.990052     0.969637
# 30    1.000000     0.972839

# %%
plt.figure(figsize=(10,5))
plt.plot(X[:,0],t.N.y_hat.flatten(),label='predicted y')
plt.plot(X[:,0],y_first.flatten(),label='observed y')
plt.legend()

# %% [markdown]
# TODO: Plot the residuals, aka observed versus predicted for y

# %%
plt.figure(figsize=(10,5))
plt.plot(X[:,0],y_first.flatten()-t.N.y_hat.flatten(),label='observed y - predicted y')
plt.legend()
plt.title("Residuals")

# %% [markdown]
# TODO: Plot cost over iterations

# %%
plot(t.J)
xlabel('Iterations')
ylabel('Cost');

# %% [markdown]
# TODO: Summarize your model

# %%
# This basic model has two input nodes, that are transferred to a hidden layer. In this hidden layer a weight is 
# applied to each input, then a sigmoid activation function is used on the summation. Next another weight is applied
# to this activation to produce an output

# %% [markdown]
# <details><summary>
# Click here for a hints (if stuck)
# </summary>
# Check the shape of y. Compare to X and values from lecture
# <br>
# <br>
# Did you normalize?
# </details>

# %% [markdown]
# -----

# %%
# Let's go crazy with very nonlinear data
# https://github.com/JoeFannie/Polynomial-Regression/blob/master/src/Polyfit%26Lasso.ipynb

n = 100
t = np.arange(0,1.0,0.001)
x = np.arange(0,1,1.0/n)
y = np.random.normal(0,0.5,n) + np.sin(2*np.pi*x*1000/1000)

plt.plot(x,y,'o');
plt.ylabel('Value');

# %%
# Fit different polynominals
for order in range(5):
    sns.regplot(x=x,
               y=y,
               order=order);

# %% [markdown]
# TODO: Create 2d array for X
#
# X[:,0] is x
# X[:,1] are random numbers

# %%
x = x.reshape(-1,1)

# %%
X_ = [[float(x[i,:]),np.random.randn()] for i in range(len(x)) ]

# %%
#normalize X_
X_ = X_/ np.amax(X_,axis=0)

# %% [markdown]
# TODO: Create the y for training the model

# %%
y_ = y

# %%
#Normalzie y_
y_ = y_ / np.amax(y,axis=0)
# move up y to be positive

y_ = (y_ - np.min(y_))/(max(y_)-min(y_))

# %% [markdown]
# TODO: Train the NN from lecture

# %%
y_ = y_.reshape(-1,1)

# %%
nn_ = NeuralNetwork(hidden=100)
t_ = Trainer(nn_)
t_.train(X_, y_, maxiter=250)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.992088
#          Iterations: 250
#          Function evaluations: 268
#          Gradient evaluations: 268

# %% [markdown]
# TODO: Plot observed for y. On the same figure, plot predicted for y. The domain is X[:,0].

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_[:,0],nn_.y_hat.flatten(),label='predicted y')
plt.scatter(X_[:,0],y_.flatten(),label='observed y')
plt.legend()

# %% [markdown]
# TODO: Plot the residuals, aka observed versus predicted for y

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_[:,0],y_.flatten()-nn_.y_hat.flatten(),label='observed y - predicted y')
plt.legend()
plt.title("Residuals")

# %% [markdown]
# TODO: Plot cost over iterations

# %%
plot(t_.J)
xlabel('Iterations')
ylabel('Cost');

# %% [markdown]
# TODO: Summarize your model

# %%
# For this model to learn a polynomial , we had to make a couple of modifications 
# 1) scale X and y to remove the mean , then also increase y to remove the negative values

# %% [markdown]
# TODO: Reflect on what you learned about neural networks

# %%
#

# %% [markdown]
# TODO: Play with http://playground.tensorflow.org/. What insights do you get?

# %% [markdown]
# -----
# Challenge Activities
# ----

# %% [markdown]
# TODO: Fit Neural Network classifier on the spiral dataset.

# %%
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D)) # data matrix (each row = single example)
y = np.zeros(N*K, dtype='uint8') # class labels
for j in range(K):
    ix = range(N*j,N*(j+1))
    r = np.linspace(0.0,1,N) # radius
    t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
    X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
    y[ix] = j

# lets visualize the data:
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral);

# %%
nn_2.y_hat
# Out:
# array([[  6.16313399e-01],
#        [  5.07830752e-04],
#        [  1.88924054e-05],
#        [  2.53876203e-05],
#        [  1.62144897e-04],
#        [  2.31016519e-06],
#        [  1.41455095e-05],
#        [  1.19565507e-02],
#        [  1.24040501e-03],
#        [  2.31050997e-08],
#        [  2.39034584e-09],
#        [  1.69661996e-08],
#        [  1.85779041e-08],
#        [  3.17032835e-05],
#        [  2.64719394e-10],
#        [  1.48330097e-09],
#        [  1.40549474e-08],
#        [  1.37714478e-08],
#        [  2.47755916e-09],
#        [  5.31181296e-10],
#        [  1.01646865e-02],
#        [  1.26445253e-10],
#        [  5.85244998e-02],
#        [  1.73526690e-01],
#        [  1.21336935e-03],
#        [  7.69108243e-04],
#        [  3.38068257e-02],
#        [  5.58270154e-03],
#        [  5.00032871e-02],
#        [  5.93080043e-06],
#        [  5.83666710e-14],
#        [  1.18784600e-13],
#        [  5.21436539e-03],
#        [  1.06677263e-03],
#        [  1.91428848e-05],
#        [  2.00903185e-03],
#        [  1.91706883e-04],
#        [  1.04341619e-01],
#        [  4.76193278e-04],
#        [  5.34740117e-02],
#        [  9.47969333e-03],
#        [  8.09303457e-02],
#        [  2.76675273e-04],
#        [  3.66183245e-03],
#        [  3.65573042e-03],
#        [  1.10846034e-02],
#        [  6.49570500e-02],
#        [  7.09565645e-04],
#        [  3.30770904e-03],
#        [  4.94854118e-03],
#        [  9.09319180e-05],
#        [  5.11716405e-03],
#        [  4.18092683e-02],
#        [  4.07425405e-04],
#        [  7.94812955e-03],
#        [  5.90621827e-02],
#        [  1.35626370e-03],
#        [  3.37836742e-02],
#        [  2.67261419e-04],
#        [  5.13039610e-03],
#        [  3.09058738e-02],
#        [  3.49017877e-02],
#        [  3.22078453e-04],
#        [  1.77704516e-02],
#        [  1.69222565e-02],
#        [  1.11543158e-02],
#        [  1.28380317e-01],
#        [  6.33525572e-03],
#        [  2.23874806e-03],
#        [  3.27912842e-03],
#        [  2.56605920e-02],
#        [  1.00962059e-02],
#        [  7.96735215e-02],
#        [  1.09467572e-01],
#        [  3.50507699e-03],
#        [  4.97284039e-02],
#        [  1.73496588e-03],
#        [  8.91887183e-02],
#        [  1.06922067e-03],
#        [  1.11384854e-03],
#        [  9.38861584e-03],
#        [  2.35917593e-03],
#        [  1.63057819e-01],
#        [  3.70280774e-02],
#        [  2.40299366e-02],
#        [  9.91442689e-02],
#        [  2.58424697e-04],
#        [  8.90091061e-03],
#        [  1.58532100e-05],
#        [  3.23186660e-02],
#        [  3.25916343e-02],
#        [  2.31777334e-03],
#        [  8.98200660e-07],
#        [  2.27234884e-07],
#        [  4.34205259e-03],
#        [  8.93589290e-08],
#        [  9.13563301e-03],
#        [  4.54820792e-03],
#        [  9.55705839e-04],
#        [  1.27010214e-01],
#        [  6.16313399e-01],
#        [  5.05467443e-01],
#        [  4.88389023e-01],
#        [  5.71085197e-01],
#        [  4.57978123e-01],
#        [  4.81976963e-01],
#        [  4.46838157e-01],
#        [  5.43008872e-01],
#        [  4.59426311e-01],
#        [  3.51301999e-01],
#        [  5.18650240e-01],
#        [  5.63509511e-01],
#        [  5.09009120e-01],
#        [  3.89951222e-01],
#        [  4.46232999e-01],
#        [  4.81751270e-01],
#        [  4.92146339e-01],
#        [  4.27042400e-01],
#        [  5.07382824e-01],
#        [  6.22525319e-01],
#        [  8.14282285e-01],
#        [  4.84707998e-01],
#        [  4.72260236e-01],
#        [  4.95279036e-01],
#        [  4.30514726e-01],
#        [  4.48241528e-01],
#        [  5.51566451e-01],
#        [  5.04274814e-01],
#        [  5.74835720e-01],
#        [  5.38511502e-01],
#        [  4.84494280e-01],
#        [  4.67333142e-01],
#        [  4.76504090e-01],
#        [  5.76657087e-01],
#        [  4.70604332e-01],
#        [  5.25383853e-01],
#        [  5.55521755e-01],
#        [  2.90889640e-01],
#        [  4.66498233e-01],
#        [  3.90298722e-01],
#        [  5.30885672e-01],
#        [  5.19785464e-01],
#        [  4.80690704e-01],
#        [  5.50601625e-01],
#        [  4.38344499e-01],
#        [  5.09992321e-01],
#        [  3.35091197e-01],
#        [  4.14656888e-01],
#        [  5.73956512e-01],
#        [  6.06638732e-01],
#        [  4.27442915e-01],
#        [  3.63047369e-01],
#        [  5.33631114e-01],
#        [  4.19402647e-01],
#        [  5.00086650e-01],
#        [  4.59036758e-01],
#        [  5.10464836e-01],
#        [  5.63911117e-01],
#        [  5.63562759e-01],
#        [  4.89044718e-01],
#        [  7.06784632e-01],
#        [  4.44820379e-01],
#        [  3.34395201e-01],
#        [  5.09962518e-01],
#        [  4.83281975e-01],
#        [  5.29130705e-01],
#        [  5.51966526e-01],
#        [  5.10151864e-01],
#        [  4.56132010e-01],
#        [  6.20172088e-01],
#        [  5.02834894e-01],
#        [  4.99780867e-01],
#        [  4.98916197e-01],
#        [  7.13836176e-01],
#        [  4.99023578e-01],
#        [  5.01411459e-01],
#        [  5.05128650e-01],
#        [  4.67247886e-01],
#        [  9.82005266e-01],
#        [  4.77573573e-01],
#        [  4.49549322e-01],
#        [  5.62347235e-01],
#        [  3.52541082e-01],
#        [  6.11633583e-01],
#        [  4.72740437e-01],
#        [  4.93112678e-01],
#        [  5.10474223e-01],
#        [  4.68187132e-01],
#        [  3.99015822e-01],
#        [  5.00113403e-01],
#        [  6.01620328e-01],
#        [  5.03270881e-01],
#        [  5.69294337e-01],
#        [  4.85554083e-01],
#        [  5.72522460e-01],
#        [  4.95834179e-01],
#        [  4.93700768e-01],
#        [  4.94087397e-01],
#        [  4.97232302e-01],
#        [  4.94129299e-01],
#        [  6.16313399e-01],
#        [  9.93829348e-01],
#        [  9.99331538e-01],
#        [  9.97254757e-01],
#        [  9.99712103e-01],
#        [  9.99849710e-01],
#        [  9.99590991e-01],
#        [  8.40640743e-01],
#        [  8.27645302e-01],
#        [  9.91252059e-01],
#        [  9.82941251e-01],
#        [  9.40570989e-01],
#        [  9.55810354e-01],
#        [  9.75868173e-01],
#        [  9.88789620e-01],
#        [  9.79816868e-01],
#        [  9.99552376e-01],
#        [  9.91096364e-01],
#        [  9.87093405e-01],
#        [  9.99496745e-01],
#        [  9.99698418e-01],
#        [  9.87558924e-01],
#        [  9.64943484e-01],
#        [  9.89803082e-01],
#        [  9.97000110e-01],
#        [  9.47832893e-01],
#        [  9.93536475e-01],
#        [  9.84050482e-01],
#        [  9.74834929e-01],
#        [  9.68014719e-01],
#        [  9.88220822e-01],
#        [  9.35763158e-01],
#        [  9.63400532e-01],
#        [  9.23392661e-01],
#        [  8.89510501e-01],
#        [  9.03701424e-01],
#        [  9.40167453e-01],
#        [  9.18965471e-01],
#        [  8.67725041e-01],
#        [  8.69846387e-01],
#        [  9.21115685e-01],
#        [  9.99999194e-01],
#        [  9.98698607e-01],
#        [  9.99995188e-01],
#        [  8.66154379e-01],
#        [  1.00000000e+00],
#        [  1.00000000e+00],
#        [  9.99904015e-01],
#        [  9.99980274e-01],
#        [  8.42201905e-01],
#        [  9.17622988e-01],
#        [  9.99528664e-01],
#        [  9.99999298e-01],
#        [  9.93459408e-01],
#        [  9.99231877e-01],
#        [  1.00000000e+00],
#        [  9.99999997e-01],
#        [  9.99999997e-01],
#        [  9.99999996e-01],
#        [  9.99999990e-01],
#        [  9.84234275e-01],
#        [  9.96106473e-01],
#        [  9.99999817e-01],
#        [  9.91254530e-01],
#        [  9.85697016e-01],
#        [  9.85858414e-01],
#        [  9.99552449e-01],
#        [  9.91256915e-01],
#        [  9.94802144e-01],
#        [  9.88215568e-01],
#        [  9.40087585e-01],
#        [  9.74060714e-01],
#        [  9.31891269e-01],
#        [  9.98483049e-01],
#        [  9.97246682e-01],
#        [  9.95134226e-01],
#        [  9.99998468e-01],
#        [  9.99985514e-01],
#        [  9.14416805e-01],
#        [  9.99924807e-01],
#        [  9.21721248e-01],
#        [  9.99999376e-01],
#        [  1.00000000e+00],
#        [  9.99999925e-01],
#        [  9.98077371e-01],
#        [  1.00000000e+00],
#        [  9.93921717e-01],
#        [  9.99196992e-01],
#        [  1.00000000e+00],
#        [  1.00000000e+00],
#        [  1.00000000e+00],
#        [  1.00000000e+00],
#        [  1.00000000e+00],
#        [  1.00000000e+00],
#        [  1.00000000e+00],
#        [  1.00000000e+00],
#        [  9.99999984e-01],
#        [  1.00000000e+00],
#        [  1.00000000e+00],
#        [  9.99999998e-01]])

# %%
#normalize X_
X= X/ np.amax(X,axis=0)

# %%
#Normalzie y_
y= y / np.amax(y,axis=0)
# move up y to be positive

y = (y - np.min(y))/(max(y)-min(y))

# %%
y = y.reshape(-1,1)

# %%
nn_2 = NeuralNetwork(200)

# %%
t_2= Trainer(nn_2)
t_2.train(X, y, maxiter=1000)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 1.295538
#          Iterations: 1000
#          Function evaluations: 1049
#          Gradient evaluations: 1049

# %%
plt.figure(figsize=(10,5))
plt.scatter(X[:,0],nn_2.y_hat.flatten(),label='predicted y')
plt.scatter(X[:,0],y.flatten(),label='observed y')
plt.legend()

# %%
plt.figure(figsize=(10,5))
plt.scatter(X[:,0],y.flatten()-nn_2.y_hat.flatten(),label='observed y - predicted y')
plt.legend()
plt.title("Residuals")

# %%
plot(t_2.J)
xlabel('Iterations')
ylabel('Cost');

# %%
plt.scatter(X[:, 0], X[:, 1], c=nn_2.y_hat, s=40, cmap=plt.cm.Spectral);

# %% [markdown]
# <details><summary>
# Click here for a hint…
# </summary>
# http://cs231n.github.io/neural-networks-case-study/
# </details>

# %% [markdown]
# -----
#
# TODO: Fit Neural Network classifier on XOR data in Chapter 6 of Deep Learning book

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
